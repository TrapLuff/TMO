# %% [markdown]
# # Лабораторная работа: Условная оптимизация

# %% [markdown]
# ## Задача 1.3:
# f(x) = x1^2 + 2*x1*x2 + (x2 - 2)^2 -> min
#
# Ограничения: g1(x) = x1^2 + x2^2 - 1 <= 0
#              g2(x) = -x1 <= 0
#              g3(x) = -x2 <= 0

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import minimize, NonlinearConstraint
from sympy import symbols, diff, solve, Matrix, hessian
import warnings
warnings.filterwarnings('ignore')
